# %%
# Import Environment Dependencies
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from config import api_key, api_key_secret, access_token,access_token_secret
from pprint import pprint
from datetime import date
from datetime import timedelta

# %%
# Get Authentication and API Handle from Tweepy

auth = tweepy.OAuthHandler(consumer_key=api_key, consumer_secret=api_key_secret)

auth.set_access_token(access_token,access_token_secret)

API = tweepy.API(auth)

# %%
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f"Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text:{ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")
  
  
# function to perform data extraction
def scrape(words, location, numtweet):
      
    # Creating DataFrame using pandas
    db = pd.DataFrame(columns=['username', 'description', 'location', 'following',
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags'])
    
    # Doing date Arithmetic to get last 10 days from today
    today = date.today()
    prior_days = timedelta(days=10)
    date_since = today - prior_days
    
    # Creating a Cursor using the .Cursor() method to search through twitter for the required tweets.
    
    # The number of tweets can be restricted using .items(number of tweets)
    
    tweets = tweepy.Cursor(API.search_tweets, q=words, lang="en",
                           since=date_since, tweet_mode='extended').items(numtweet)
     
    # .Cursor() returns an iterable object. Each item in 
    # the iterator has various attributes that you can access to 
    # get information about each tweet
    list_tweets = [tweet for tweet in tweets]
      
    # Counter to maintain Tweet Count
    i = 1  
      
    # we will iterate over each tweet in the list for extracting information about each tweet
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
        
        
        # Retweets can be distinguished by a retweeted_status attribute,
        # in case it is an invalid reference, except block will be executed
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
          
        # Here we are appending all the extracted information in the DataFrame
        ith_tweet = [username, description, location, following,
                     followers, totaltweets, retweetcount, text, hashtext]
        db.loc[len(db)] = ith_tweet
          
        # Function call to print tweet data on screen
        printtweetdata(i, ith_tweet)
        i = i+1
    
#     filename = 'scraped_tweets.csv'
      
    # Saving the resultset as a CSV file.
#     db.to_csv(filename)
  
  
if __name__ == '__main__':
         
    # Enter Hashtag and initial date
    print("Enter Twitter HashTag to search for")
    words = input()
    #     print("Enter Date since The Tweets are required in yyyy-mm--dd")
    #     date_since = input()
    print("Enter Location of Tweets are required")
    location = input()
    
    # number of tweets you want to extract in one run
    numtweet = 100  
    #     scrape(words, date_since, numtweet)
   
    # Call the scrape function to get the Tweets matching our criteria
    scrape(words, location, numtweet)
    print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# braves
# Enter Location of Tweets are required
# atlanta
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Tweet 1:
# Username:N_Bats
# Description:
# Location:
# Following Count:69
# Follower Count:46
# Total Tweets:158
# Retweet Count:0
# Tweet Text:@GreekBaseball @Braves Fk the braves but go Hellas 🇬🇷 yiasou patrida
# Hashtags Used:[]
#
# Tweet 2:
# Username:missjuliek
# Description:Braves diehard. FSU football. Flyers. Eagles. Villanova hoops. NASCAR. WWE. Crime shows. Craft beer. Bookworm.
# Location:Hummelstown, Pennsylvania
# Following Count:742
# Follower Count:431
# Total Tweets:120010
# Retweet Count:76
# Tweet Text:A picture worth a million words.
#
# I'm still thinking about Game 6, the #Braves' biggest win in over two decades and the #Postseason heroes who helped Atlanta make it back to the #WorldSeries. https://t.co/tpBnj4dzi9
# Hashtags Used:['Braves']
#
# Tweet 3:
# Username:CarpenterJimS
# Description:Self-employed builder, all things Hokies fan, Steelers fan, and I vote Republican but I'm more independent. (pro weed) Trying to avoid stupid people. F@*k UVA
# Location:Fairlawn, VA
# Following Count:828
# Follower Count:526
# Total Tweets:69849
# Retweet Count:643
# Tweet Text:Atlanta Braves are in the World Series. Does that mean since Georgia is racist with their voting laws they will be moving the World Series to another city?
# Hashtags Used:[]
#
# Tweet 4:
# Username:JJBravesfan
# Description:#Dawgs Alumnus, #Braves believer. Georgia boy who’s finally returned home. Founding member of the #RSC.
# Location:Atlanta, GA
# Following Count:703
# Follower Count:140
# Total Tweets:2555
# Retweet Count:3
# Tweet Text:@Braves Series is over
# Hashtags Used:[]
#
# Tweet 5:
# Username:ChattanoogaApp
# Description:A webapp for the greater Chattanooga region, and the best way to stay up-to-date with local news and content as it happens. Email: feedback@mychattanooga.app
# Location:
# Following Count:8
# Follower Count:61
# Total Tweets:5570
# Retweet Count:0
# Tweet Text:Braves fans in Chattanooga react to NLCS victory
#
# Published by Fox Chattanooga at 11:16 PM
#
# https://t.co/CM2zvV3xob
# Hashtags Used:[]
#
# Tweet 6:
# Username:spacie16
# Description:Cali Gal, diehard Seattle Mariners fan and Disney freak, trying to find her place in the world...
# Location:Pasco, WA
# Following Count:1350
# Follower Count:242
# Total Tweets:13568
# Retweet Count:1
# Tweet Text:LETS FUCKING GO @Braves! YOU ARE NOW AMERICA’S TEAM! GO BEAT THOSE ASTROS!
# Hashtags Used:[]
#
# Tweet 7:
# Username:kimmons_mike
# Description:
# Location:Friendswood, Texas
# Following Count:86
# Follower Count:11
# Total Tweets:13
# Retweet Count:0
# Tweet Text:@ChrisWojdyla Living in Houston, I hope the Braves sweep 'em.
# Hashtags Used:[]
#
# Tweet 8:
# Username:anygivenpod
# Description:A year-round #NFL Podcast with a Dynasty Fantasy Football spin! Co-hosted by @JoshGoldbergAGP & @WillieBeamanDFF #SFBX #SFB11 #DU1
# Location:South Florida
# Following Count:980
# Follower Count:1028
# Total Tweets:5349
# Retweet Count:30
# Tweet Text:🚨 Five Minute Free For All!🚨
#
# #MLB @Braves advance to the #WorldSeries, a wild #CollegeFootball Saturday and more!
#
# https://t.co/mdcYdyKlk4
# Hashtags Used:['MLB', 'WorldSeries', 'CollegeFootball']
#
# Tweet 9:
# Username:CF7_Era
# Description:@MissDewey14 🖤🌹
# Location:
# Following Count:515
# Follower Count:4285
# Total Tweets:166651
# Retweet Count:0
# Tweet Text:Let’s go Braves https://t.co/k7ndB1yLvS
# Hashtags Used:[]
#
# Tweet 10:
# Username:Abrahamus15
# Description:2nd Gen Immigrant. Combat Vet. Poor for 32 years but succeeded to a good life. Against socialism, communism, and Democrats who want to put Americans last.
# Location:
# Following Count:33
# Follower Count:1
# Total Tweets:195
# Retweet Count:643
# Tweet Text:Atlanta Braves are in the World Series. Does that mean since Georgia is racist with their voting laws they will be moving the World Series to another city?
# Hashtags Used:[]
#
# Tweet 11:
# Username:jbarGT
# Description:RIPTMLNS👼🏿. Alexander Paul Wasko
# Location:
# Following Count:296
# Follower Count:216
# Total Tweets:7288
# Retweet Count:457
# Tweet Text:Holy shit this video
#
#  https://t.co/WOvRwaATaw
# Hashtags Used:[]
#
# Tweet 12:
# Username:713BigRo
# Description:...
# Location:Houston, Texas.
# Following Count:802
# Follower Count:364
# Total Tweets:7870
# Retweet Count:1
# Tweet Text:@SDFriarGirl @theorangethrone @JWSv2_ @MLBNetwork @MLB @Braves @astros Nah, I like the Astros slapping around Boston and Oakland and NY and so on...
# Hashtags Used:[]
#
# Tweet 13:
# Username:AmpFloyd
# Description:
# Location:
# Following Count:808
# Follower Count:178
# Total Tweets:2944
# Retweet Count:0
# Tweet Text:@braves_aruba @Braves We had to too. https://t.co/2dfzVFRsLv
# Hashtags Used:[]
#
# Tweet 14:
# Username:ferentinos_j
# Description:Conservative since 1991; naive regarding my principles before marriage Forget blessing us; “God Help America” ❤️🇺🇸#adoremyhusbandandkids
# Location:
# Following Count:733
# Follower Count:77
# Total Tweets:1787
# Retweet Count:0
# Tweet Text:@Kennysus OMG GO BRAVES 🪓🪓🪓! I’m so optimistically, incredibly proud of this young Braves team! Beating the WS Champions is a feat in &amp; of itself❤️Now, our beloved Atlanta Braves have qualified to play in in the World Series! They’ve earned it❤️🙏👍🏆
# Hashtags Used:[]
#
# Tweet 15:
# Username:akdavemtp
# Description:Braves fan. Alaskan.
# Location:
# Following Count:47
# Follower Count:35
# Total Tweets:375
# Retweet Count:0
# Tweet Text:@Jim_Powell @Braves @MLB Sorry we didn’t listen last night - we couldn’t have heard you anyway! This was so worth the trip from Alaska. Go Braves! (We do listen all summer!) https://t.co/KOipD0F1g1
# Hashtags Used:[]
#
# Tweet 16:
# Username:cbs46
# Description:Atlanta! We're your home for CBS. Watch us from 4:30-7a, at 12Noon, 4-6:30p and 11p and we're always on at https://t.co/J6xLsht4TL, Instagram: @CBS46, Facebook: CBS46
# Location:Atlanta, Ga.
# Following Count:2321
# Follower Count:101395
# Total Tweets:267450
# Retweet Count:1
# Tweet Text:Have you picked up any new @Braves gear??
# https://t.co/M7EG4RO3PM
# Hashtags Used:[]
#
# Tweet 17:
# Username:LockStockDaDon
# Description:Frank
# Location:Brooklyn, NY
# Following Count:176
# Follower Count:45
# Total Tweets:1140
# Retweet Count:2053
# Tweet Text:Are the @Braves going to play the World Series in Georgia or is voter suppression no longer a thing? @MLB
# Hashtags Used:[]
#
# Tweet 18:
# Username:007_Agent_
# Description:RT’s are not endorsements       “Life’s not fair”  #GamebredFC      #ChiefsKingdom #SLU #Billikens #Blues #Cardinals #Mizzou #OKC #Thunder #OkSt
# Location:
# Following Count:189
# Follower Count:126
# Total Tweets:36751
# Retweet Count:6573
# Tweet Text:So the wing nut cancel culture tried to pressure the Atlanta Braves into forcing me not to sing the National Anthem at Game 6 of the NLCS. I’m so thankful that the @braves did not cave to this pressure and refused to be bullied. Thanks for allowing me to pay tribute to America.🇺🇸
# Hashtags Used:[]
#
# Tweet 19:
# Username:georgiaboy981
# Description:Married father of three! GO DAWGS GATA! #2A #Flkeys #30A  #Godawgs  🇺🇸  #MAGA  Followed by Herschel Walker! Dog lovers check out my wife's website ⬇
# Location:South Carolina, USA
# Following Count:2610
# Follower Count:2488
# Total Tweets:48161
# Retweet Count:19
# Tweet Text:A Braves WS would be nice, but will take a Dawgs Natty a 1000 times more.
# Hashtags Used:[]
#
# Tweet 20:
# Username:malcolmxhodge
# Description:personal finance geek. frequent flyer. philanthropist. supply chain + strategy @nike. nc a&t alum // ig: malcolmxhodge
# Location:Everywhere
# Following Count:454
# Follower Count:1982
# Total Tweets:18371
# Retweet Count:1716
# Tweet Text:WE’RE GOING TO THE WORLD SERIES!!!
#
# #BattleATL x @Braves https://t.co/HohWtReqG8
# Hashtags Used:['BattleATL']
#
# Tweet 21:
# Username:cbs46
# Description:Atlanta! We're your home for CBS. Watch us from 4:30-7a, at 12Noon, 4-6:30p and 11p and we're always on at https://t.co/J6xLsht4TL, Instagram: @CBS46, Facebook: CBS46
# Location:Atlanta, Ga.
# Following Count:2321
# Follower Count:101395
# Total Tweets:267450
# Retweet Count:1
# Tweet Text:Let’s go BRAVES. Join us at 11:30 for all your Braves highlights https://t.co/6XmoZbfCyd
# Hashtags Used:[]
#
# Tweet 22:
# Username:JBristolKHOU
# Description:Emmy® award-winning TV sports storyteller at @KHOU. Tweets are my own; RTs not endorsements. #315 #716 #717 now #713 Tips: jbristol@khou.com
# Location:Houston, TX
# Following Count:1181
# Follower Count:3666
# Total Tweets:44097
# Retweet Count:0
# Tweet Text:Coming up on Sports Extra at 11pm:
# @SethCPayne on Deshaun Watson trade possibility; @_JeremyBooth on what should scare Astros fans about the Braves; and comedian @ChineduOgu on what may be his new look thru end of October. https://t.co/R1SqYeZRFN
# Hashtags Used:[]
#
# Tweet 23:
# Username:MikeyLambert3
# Description:ASU 22’
# Location:
# Following Count:1759
# Follower Count:685
# Total Tweets:10890
# Retweet Count:516
# Tweet Text:Another battle. Another VICTORY.
#
# #BattleATL | #KillTheNarrative https://t.co/ahDowtQGqI
# Hashtags Used:['BattleATL', 'KillTheNarrative']
#
# Tweet 24:
# Username:AdamGenez
# Description:Haven’t fully decided what I’ll be doing on here yet, but you can follow me if you’d like. Any suspicious users will be blocked
# Location:Houston, TX
# Following Count:29
# Follower Count:15
# Total Tweets:1518
# Retweet Count:0
# Tweet Text:@CjWieringa17 @StevenStuntin @MLB Braves only made the playoffs cause the rest of the NL East is weak.
# Hashtags Used:[]
#
# Tweet 25:
# Username:713BigRo
# Description:...
# Location:Houston, Texas.
# Following Count:802
# Follower Count:364
# Total Tweets:7870
# Retweet Count:151
# Tweet Text:18 innings. The only Postseason game in @MLB history in which both teams hit a grand slam. The Rocket's only career win in relief.
#
# A look back at the epic 2005 NLDS Game 4 matchup between the @Braves &amp; @astros. https://t.co/unG9zQ4x1i
# Hashtags Used:[]
#
# Tweet 26:
# Username:KrakRmaN85
# Description:Small town survivor from Blakely, GA. Dawg fan
# Location:Mobile, AL
# Following Count:726
# Follower Count:100
# Total Tweets:5994
# Retweet Count:457
# Tweet Text:Holy shit this video
#
#  https://t.co/WOvRwaATaw
# Hashtags Used:[]
#
# Tweet 27:
# Username:KorySburner
# Description:Told myself I’d stay away, but had to come back to troll the Dodgers fanbase and Bill Plaschke. Everthing Braves, Baseball, Alabama Football, College football.
# Location:
# Following Count:175
# Follower Count:17
# Total Tweets:97
# Retweet Count:0
# Tweet Text:When you try to sleep but your Doberman is still excited the @Braves are going to the World Series. https://t.co/jGCDj7gD4y
# Hashtags Used:[]
#
# Tweet 28:
# Username:JaredOffAir
# Description:Free Agent Radio Personality, Kidney Transplant Recipient, Afraid of Escalators, Braves/Golden Knights/Aggie Fan, Atlanta and Vegas Raised.
# Location:San Antonio, TX
# Following Count:1622
# Follower Count:11529
# Total Tweets:24803
# Retweet Count:0
# Tweet Text:@lared_s Braves all the way.
# Hashtags Used:[]
#
# Tweet 29:
# Username:esalva23
# Description:
# Location:
# Following Count:113
# Follower Count:26
# Total Tweets:128
# Retweet Count:4309
# Tweet Text:#ChopOn
#
# The @Braves have won the NL Pennant and are moving onto the World Series! #CLINCHED https://t.co/dL8Zb0Vx1M
# Hashtags Used:['ChopOn', 'CLINCHED']
#
# Tweet 30:
# Username:podcast_kitchen
# Description:A podcast that focuses on hot points of @cra5hD and Bubba Jay's life.  Based on the Kitchen Conversations held around Jay's family table.🔃=/=👍
# Location:Indianapolis, IN
# Following Count:325
# Follower Count:206
# Total Tweets:101724
# Retweet Count:7
# Tweet Text:Framber Valdez will start Game 1 of the World Series for the Astros against the Braves' Charlie Morton. Houston did not announce a starter for Game 2.
#
# By @kristieAP: https://t.co/FD3KJEhZX2
# Hashtags Used:[]
#
# Tweet 31:
# Username:taylortrinkwon
# Description:| OC | University of San Diego Alum | “The words that follow I am, follow you”| Lefty Golfer | Mortgage Advisor |
# Location:
# Following Count:179
# Follower Count:210
# Total Tweets:8477
# Retweet Count:63
# Tweet Text:The Braves: Playing for a World Series title
#
# The Hawks: Made the ECF last year
#
# UGA: The undisputed No. 1 team in College Football
#
# The Falcons:
# Hashtags Used:[]
#
# Tweet 32:
# Username:WSportspicks
# Description:Pro Capper- ⭐️278-163 in MLB since JUNE 1st) 185-123 Overall NBA 20-21🔥 DM ME about @VIPWicks for the best Picks!🤑 24-7 NFL START!! 🔥14-8 NCAAF 💥
# Location:
# Following Count:975
# Follower Count:1331
# Total Tweets:1594
# Retweet Count:0
# Tweet Text:@loyderII @Buster_ESPN You’re mad your expensive ass Yankees team can’t get close to matching up with the Braves right now. Without one of the best players in the MLB if not the current best this year before injury. That’s cute. Shed a tear for me plz
# Hashtags Used:[]
#
# Tweet 33:
# Username:T_McDaniel1017
# Description:|28| #Gamecocknation #FalconNation #LebronJames IG: @TMcDaniel803 #StriveForGreatness SC: @tylerm803
# Location:
# Following Count:508
# Follower Count:521
# Total Tweets:53243
# Retweet Count:2799
# Tweet Text:11 seasons. 1,565 games played. 6,660 plate appearances. All in an Atlanta Braves uniform.
#
# Freddie Freeman is headed to his first World Series. https://t.co/t4njz9G4v3
# Hashtags Used:[]
#
# Tweet 34:
# Username:ATX_NickSchmitt
# Description:
# Location:Austin, TX
# Following Count:226
# Follower Count:23
# Total Tweets:1954
# Retweet Count:2976
# Tweet Text:Braves to the World Series. Will @MLB force them to play their home games in Colorado?
# Hashtags Used:[]
#
# Tweet 35:
# Username:I_am_Steele
# Description:Technical Director and Lighting Designer- US Citizen living abroad.
# Location:Toronto, ON Canada
# Following Count:1208
# Follower Count:985
# Total Tweets:33544
# Retweet Count:0
# Tweet Text:@spencerosborne @PatMac14012450 @Travistritt @Braves It is funny that you refuse to show any work.
#
# And it is also really funny that every single person who complains about "mandates" always points to Israel for answers, but doesn't ever actually look at the Israeli data (80% vaccinated, nearly all their cases in unvaccinated).
# Hashtags Used:[]
#
# Tweet 36:
# Username:honeymilkyway19
# Description:美味い珈琲・サンドウィッチを味わいに各地の珈琲屋・パン屋を巡る…いいねは必ずしも内容に賛意を示すものではありません。
# Location:日本
# Following Count:300
# Follower Count:88
# Total Tweets:9346
# Retweet Count:2
# Tweet Text:The pennant-winning Braves and a magical Saturday night https://t.co/yHT8LqbZlh
# Hashtags Used:[]
#
# Tweet 37:
# Username:JJBravesfan
# Description:#Dawgs Alumnus, #Braves believer. Georgia boy who’s finally returned home. Founding member of the #RSC.
# Location:Atlanta, GA
# Following Count:703
# Follower Count:140
# Total Tweets:2555
# Retweet Count:1
# Tweet Text:@BravesFromLA There is one superpower in the NL
#
# The Brewers aren’t the giants aren’t the Braves aren’t.
#
# If somehow LA loses a wildcard or best of 5….it’s anyone’s
#
# (Nobody is beating them in a best of 7)
# Hashtags Used:[]
#
# Tweet 38:
# Username:buffalobro3939
# Description:Aimin' at your head, like a buffalo
# Location:
# Following Count:357
# Follower Count:12
# Total Tweets:336
# Retweet Count:0
# Tweet Text:@ByMHarrington @TBNSports Lol. Even harringtons baseball takes are horrible. Braves are one of the hottest teams in baseball. Have 2 aces in morton and fried and a dangerous lineup with 2 mvp candidates. 11 teams better. Idiot!
# Hashtags Used:[]
# Tweet 39:
# Username:jspringmeyer
# Description:Proud LIBERAL trying to find a balance between kids, work, fly fishing and golf. Utes, Jazz, Dodgers. #singledadlife
# Location:Salt Lake City, Utah
# Following Count:617
# Follower Count:94
# Total Tweets:3504
# Retweet Count:0
# Tweet Text:Congratulations to the Atlanta @Braves and to all their fans. On behalf of @Dodgers fans everywhere, and fans of teams that don’t cheat, please…
# Kick. Houston’s. Ass!!!! 🗑🗑🗑
# Hashtags Used:[]
#
# Tweet 40:
# Username:AmpFloyd
# Description:
# Location:
# Following Count:808
# Follower Count:178
# Total Tweets:2944
# Retweet Count:0
# Tweet Text:@olisamir @TheNatidude I think the Travis Tritt thing was actually because it was 30 years to the day that he sang the anthem at the Braves first home World Series game vs Minnesota. But yeah, optics weren’t great. And again Atlanta is different than GA.
# Hashtags Used:[]
#
# Tweet 41:
# Username:Dillard4453
# Description:72 Baby..........American-African......Play hard with no disregard....if u get offended by free speech and free expression....do not follow me.
# Location:The Mississippi
# Following Count:1999
# Follower Count:186
# Total Tweets:1972
# Retweet Count:23999
# Tweet Text:THE ATLANTA BRAVES ARE GOING TO THE WORLD SERIES!
#
# #BattleATL https://t.co/gk7eomQdle
# Hashtags Used:['BattleATL']
#
# Tweet 42:
# Username:Shultsdaley
# Description:notre dame / Tennessee Titans / Atlanta braves / usmnt / Atlanta united fc/canes hockey /father of 2/ greatest thing to happen to the rgv since space x
# Location:Rio grande valley
# Following Count:1150
# Follower Count:295
# Total Tweets:7861
# Retweet Count:661
# Tweet Text:Sound 🆙 for that magical moment!
#
# @Braves l #BattleATL l NTT #ClinchCam https://t.co/VCGWf3r6Ga
# Hashtags Used:['BattleATL', 'ClinchCam']
#
# Tweet 43:
# Username:ConboyGreta
# Description:Joshua 1:9 // Life happens. Coffee helps.
# Location:Atlanta, GA
# Following Count:322
# Follower Count:428
# Total Tweets:3012
# Retweet Count:516
# Tweet Text:Another battle. Another VICTORY.
#
# #BattleATL | #KillTheNarrative https://t.co/ahDowtQGqI
# Hashtags Used:['BattleATL', 'KillTheNarrative']
#
# Tweet 44:
# Username:DamarisElizond3
# Description:Love my life, Theme Parks, Concerts, New Adventures,LoveMakeup, Love Nails 💅🏽 ❤️👸🏽💃🏽🎒👑 Daytona Beach 🌊
# Location:Port Orange, FL
# Following Count:542
# Follower Count:27
# Total Tweets:431
# Retweet Count:23999
# Tweet Text:THE ATLANTA BRAVES ARE GOING TO THE WORLD SERIES!
#
# #BattleATL https://t.co/gk7eomQdle
# Hashtags Used:['BattleATL']
#
# Tweet 45:
# Username:thehuntinghippi
# Description:woods. water. poetry. love.
# Husband and father to two beautiful children.
# Location:North Georgia
# Following Count:274
# Follower Count:45
# Total Tweets:727
# Retweet Count:0
# Tweet Text:@MikeI44444 @JonHeyman Braves have more fans across the nation than all teams excluding Yanks and Dodgers. Sorry, it's true. And you can thank Ted Turner for that.
# Now go to sleep.
# Hashtags Used:[]
#
# Tweet 46:
# Username:wrgates
# Description:There may be people that have more talent than you, but there's no excuse for anyone to work harder than you do! -Derek Jeter
# Location:Texas, USA
# Following Count:579
# Follower Count:317
# Total Tweets:3236
# Retweet Count:135
# Tweet Text:Sidenote: Brian Snitker and the Braves coaching staff will manage the 2022 All-Star game in Dodger Stadium 😎
# Hashtags Used:[]
#
# Tweet 47:
# Username:Willy_Vanilly_
# Description:
# Location:Suntrust Park
# Following Count:937
# Follower Count:534
# Total Tweets:14279
# Retweet Count:775
# Tweet Text:.@TylerMatzek appreciation Tweet.
#
# #CarryTheFreight | #BattleATL https://t.co/ppR1CWOugV
# Hashtags Used:['CarryTheFreight', 'BattleATL']
#
# Tweet 48:
# Username:CAPearson13
# Description:A proud Christian, UGA alumni, and a ravid Bulldogs fan. I also enjoy video games.
# Location:
# Following Count:395
# Follower Count:217
# Total Tweets:4075
# Retweet Count:1
# Tweet Text:I made this account back in March simply to interact with Braves fans. Y’all are all awesome af. Thank y’all so much for making this app so freaking fun and awesome!
# Hashtags Used:[]
#
# Tweet 49:
# Username:aufootball
# Description:Former publisher and writer at https://t.co/ZN8kRio2aH, https://t.co/XC8cppaIAg
# Location:Birmingham, AL
# Following Count:398
# Follower Count:278
# Total Tweets:6216
# Retweet Count:3045
# Tweet Text:Braves! Major League Baseball pulled the all star game from Atlanta this year and the Braves responded with their first World Series this century! Glorious karma. Love it!
# Hashtags Used:[]
#
# Tweet 50:
# Username:RileysRakes
# Description:Advocate for the reigning, defending, undisputed National League Champion Atlanta Braves. I play “Alex” on the Chatting Average Podcast @AverageChatting
# Location:Atlanta, GA
# Following Count:756
# Follower Count:9075
# Total Tweets:70371
# Retweet Count:2
# Tweet Text:With the Braves win last night this tradition continues https://t.co/uZ4Yufbn3d
# Hashtags Used:[]
#
# Tweet 51:
# Username:KyleWhisenhant
# Description:LU Alumni   #ForTheH
# Location:Kountze, Texas
# Following Count:690
# Follower Count:1018
# Total Tweets:16153
# Retweet Count:151
# Tweet Text:18 innings. The only Postseason game in @MLB history in which both teams hit a grand slam. The Rocket's only career win in relief.
#
# A look back at the epic 2005 NLDS Game 4 matchup between the @Braves &amp; @astros. https://t.co/unG9zQ4x1i
# Hashtags Used:[]
#
# Tweet 52:
# Username:nathanpgale
# Description:I do these 5 things: 🍔 Burgers, ⚾️ Braves, 👨🏻‍💻 Design, 🥃 Drink, and 🎢 Disney Theme Parks. I do them unashamedly and mostly for pleasure.
# Location:Portland, Oregon
# Following Count:1040
# Follower Count:225
# Total Tweets:8955
# Retweet Count:76
# Tweet Text:A picture worth a million words.
#
# I'm still thinking about Game 6, the #Braves' biggest win in over two decades and the #Postseason heroes who helped Atlanta make it back to the #WorldSeries. https://t.co/tpBnj4dzi9
# Hashtags Used:['Braves']
#
# Tweet 53:
# Username:griffdapoet
# Description:#Titans, #Astros, and #Rockets Fan 4LIFE!
#
#
# *ADVISORY: I comment on and post various topics that interest ME, MYSELF, and I 🤷🏿‍♂️
# #LIVELIFE
# Location:Houston, TX
# Following Count:5002
# Follower Count:845
# Total Tweets:147140
# Retweet Count:894
# Tweet Text:On the mound for Game 1 of the #WorldSeries:
#
# #BattleATL https://t.co/DsrlV40NFq
# Hashtags Used:['WorldSeries', 'BattleATL']
#
# Tweet 54:
# Username:ChrisYow14
# Description:Multimedia Director of @mainstreetmaury, member TSWA. Country music and Braves ⚾️ Consume way too much of my time. Email | cyow@mainstreetmediatn.com
# Location:Nashville, TN
# Following Count:1607
# Follower Count:1953
# Total Tweets:55758
# Retweet Count:0
# Tweet Text:The only pitcher that’s ever improved under Braves’ tutelage it seems. https://t.co/jqkzFrks9w
# Hashtags Used:[]
#
# Tweet 55:
# Username:SmashvilleKP
# Description:Father. Son. Brother. Friend. Grandson. Songwriter. Music maker. Fan of the Braves, Titans, Preds, & Clemson. Thinks Freddie Mercury hung the moon.h
# Location:Mount Juliet, TN
# Following Count:2121
# Follower Count:363
# Total Tweets:19817
# Retweet Count:0
# Tweet Text:I still can’t wrap my head around the fact that my Braves are playing in the World Series. It’s absolutely surreal. https://t.co/1XcenvDD41
# Hashtags Used:[]
#
# Tweet 56:
# Username:hadlgr
# Description:Ig: hadlgr
# Location:Fuera del planeta
# Following Count:995
# Follower Count:3701
# Total Tweets:108225
# Retweet Count:2799
# Tweet Text:11 seasons. 1,565 games played. 6,660 plate appearances. All in an Atlanta Braves uniform.
#
# Freddie Freeman is headed to his first World Series. https://t.co/t4njz9G4v3
# Hashtags Used:[]
#
# Tweet 57:
# Username:pujiantoandii
# Description:Family man, amat menyukai #OnePiece dan #ManchesterUnited, dan keluarga juga. Menikmati hidup dengan ala kadarnya.
#
# keluarga besar @IndoManUtd_kr
# Location:lubang kunci kamar mandi
# Following Count:489
# Follower Count:94
# Total Tweets:12809
# Retweet Count:3669
# Tweet Text:Heading to the World Series like https://t.co/w84w7Y6oyV
# Hashtags Used:[]
#
# Tweet 58:
# Username:Phantompower311
# Description:Hard work pays off, dreams come true. Bad times don't last....but bad guys do.- Scott Hall
# Location:
# Following Count:284
# Follower Count:44
# Total Tweets:951
# Retweet Count:23999
# Tweet Text:THE ATLANTA BRAVES ARE GOING TO THE WORLD SERIES!
#
# #BattleATL https://t.co/gk7eomQdle
# Hashtags Used:['BattleATL']
#
# Tweet 59:
# Username:isballsontour
# Description:clemson alum
# Location:Atlanta, GA
# Following Count:262
# Follower Count:257
# Total Tweets:7330
# Retweet Count:870
# Tweet Text:"wow. The Dodgers and Giants each won over 105 games this season. No one is beating them in the NL."
#
# @Braves: https://t.co/reD0pLQ4qE
# Hashtags Used:[]
#
# Tweet 60:
# Username:LesleyJWilliams
# Description:Overthinking everything since 1960. White, middle-class, privileged, but learning. Coffee snob. No creepy DMs. #FBR #HouseModerna #BLM #Ally #NeverTheFormerGuy
# Location:Seattle
# Following Count:6840
# Follower Count:6524
# Total Tweets:3903
# Retweet Count:0
# Tweet Text:@Travistritt @Braves You mean your tribute to your ego and hubris.
# Hashtags Used:[]
#
# Tweet 61:
# Username:WimboMoney
# Description:Digital Entrepreneur - IG: tevarus_wimbo - Forex Investor/Mentor |  Lets share goals ✊🏾 and food 😌| THIS IS SOCIAL MEDIA… not real life remember that 👌🏾
# Location:Atlanta, GA
# Following Count:337
# Follower Count:345
# Total Tweets:12717
# Retweet Count:0
# Tweet Text:Really wanted to go see the Braves in the World Series. But I’m not about to pay $1000+ for no ticket to stand up… lmao naw
# Hashtags Used:[]
#
# Tweet 62:
# Username:RobinsonGeri
# Description:
# Location:ARIZONA
# Following Count:1662
# Follower Count:1694
# Total Tweets:38729
# Retweet Count:643
# Tweet Text:Atlanta Braves are in the World Series. Does that mean since Georgia is racist with their voting laws they will be moving the World Series to another city?
# Hashtags Used:[]
#
# Tweet 63:
# Username:ChrisDeese_24
# Description:Electrical Engineer | @UofAlabama Alumnus 19’ | I Corinthians 2:9 | @williams2575 💍
# Location:Alabama, USA
# Following Count:327
# Follower Count:211
# Total Tweets:7547
# Retweet Count:76
# Tweet Text:A picture worth a million words.
#
# I'm still thinking about Game 6, the #Braves' biggest win in over two decades and the #Postseason heroes who helped Atlanta make it back to the #WorldSeries. https://t.co/tpBnj4dzi9
# Hashtags Used:['Braves']
#
# Tweet 64:
# Username:trillstepcat
# Description:Pure and moral gambler. Let’s go Brandon. #jerseyjerryarmy @jerrythekid21
# Location:Milton, MA
# Following Count:97
# Follower Count:13
# Total Tweets:253
# Retweet Count:2976
# Tweet Text:Braves to the World Series. Will @MLB force them to play their home games in Colorado?
# Hashtags Used:[]
#
# Tweet 65:
# Username:chrisjherold
# Description:Georgia Sports Homer
# Location:
# Following Count:86
# Follower Count:36
# Total Tweets:3638
# Retweet Count:0
# Tweet Text:@A_Huffstutler @RileysRakes @Braves @BravesOnBally @BravesRadioNet @BlooperBraves @PaulByrd36 @PeterMoylan @IngramRadio @Kelly_Crull @BallySportsSO @TruistPark 3) Tyler Matzek’s schlong 🐘. 11) Soler Power is BACK. 12) Joc is our king, buy some pearls, we’re all bad bitches. 13) always post the Office meme with Michael Scott happy crying when you see Ronnie. 14) Flashlight Chop is the best experience in baseball. 15) #killthenarrative
# Hashtags Used:['killthenarrative']
#
# Tweet 66:
# Username:JimmyDalton68
# Description:If you take everything I have accomplished in my entire life and condense it down into one day...it looks decent. mAcro beer enthusiast. UGA ‘99. Dawgs, Braves.
# Location:Fullers Park
# Following Count:2582
# Follower Count:103
# Total Tweets:5693
# Retweet Count:1760
# Tweet Text:Mood.
#
# #BattleATL https://t.co/NSSLEnXqTf
# Hashtags Used:['BattleATL']
#
# Tweet 67:
# Username:samsinger_1
# Description:AU Alumni
# Location:Auburn, AL
# Following Count:353
# Follower Count:355
# Total Tweets:1487
# Retweet Count:2320
# Tweet Text:They waited 22 years to celebrate like this 🥳
#
# (via @Braves)
#
# https://t.co/YfYlHoDzi8
# Hashtags Used:[]
#
# Tweet 68:
# Username:betoec19
# Description:
# Location:
# Following Count:510
# Follower Count:59
# Total Tweets:41
# Retweet Count:775
# Tweet Text:.@TylerMatzek appreciation Tweet.
#
# #CarryTheFreight | #BattleATL https://t.co/ppR1CWOugV
# Hashtags Used:['CarryTheFreight', 'BattleATL']
#
# Tweet 69:
# Username:fulham_jim
# Description:In our country the lie has become not just a moral category but a pillar of the State.
# Aleksandr Solzhenitsyn
# Location:
# Following Count:1381
# Follower Count:261
# Total Tweets:17611
# Retweet Count:1
# Tweet Text:May I join all of America in saying...Go @Braves!
# Hashtags Used:[]
#
# Tweet 70:
# Username:LaflareTMC
# Description:formerly known as 1joshlaflare
# Location:Atlanta, GA
# Following Count:319
# Follower Count:449
# Total Tweets:29343
# Retweet Count:0
# Tweet Text:UGA/Hawks/Braves on da same day is gonna send me to the ER
# Hashtags Used:[]
#
# Tweet 71:
# Username:pynkii_pants
# Description:Fat Dabs & Good Vibes💞
# CA➡️AZ➡️NV👽
# Location:Platform 9¾
# Following Count:675
# Follower Count:227
# Total Tweets:21263
# Retweet Count:976
# Tweet Text:One request, Braves.
#
# Take those cheaters to the woodshed.
# Hashtags Used:[]
#
# Tweet 72:
# Username:HOFcardsforsale
# Description:Buying and selling sports cards. Always buying baseball/football/basketball and entertainment. Message me with any questions ✌🏼
# Location:
# Following Count:1918
# Follower Count:4222
# Total Tweets:30565
# Retweet Count:0
# Tweet Text:Check out 2019 Panini Diamond Kings Ronald Acuna Jr dual jersey patch card Braves https://t.co/Wvnbbo7UDw @eBay
# Hashtags Used:[]
#
# Tweet 73:
# Username:ears4you
# Description:husband, father, son, grandson and brother
# Location:
# Following Count:3121
# Follower Count:265
# Total Tweets:18489
# Retweet Count:6573
# Tweet Text:So the wing nut cancel culture tried to pressure the Atlanta Braves into forcing me not to sing the National Anthem at Game 6 of the NLCS. I’m so thankful that the @braves did not cave to this pressure and refused to be bullied. Thanks for allowing me to pay tribute to America.🇺🇸
# Hashtags Used:[]
#
# Tweet 74:
# Username:gifs_baseball
# Description:Fully Vaccinated Braves Fan |
# Featured on NYT & https://t.co/u8XvkzzuNp
# Location:
# Following Count:122
# Follower Count:1063
# Total Tweets:783
# Retweet Count:0
# Tweet Text:(via r/Braves) https://t.co/BKmpNQdfkl
# Hashtags Used:[]
#
# Tweet 75:
# Username:Dillard4453
# Description:72 Baby..........American-African......Play hard with no disregard....if u get offended by free speech and free expression....do not follow me.
# Location:The Mississippi
# Following Count:1999
# Follower Count:186
# Total Tweets:1972
# Retweet Count:11
# Tweet Text:#Braves President Derek Schiller talks about the importance of ending the “Atlanta Sports Curse”
# Narrative from the media.
#
# #ForTheA #BravesWorldSeriesBound https://t.co/XmM9bmleWO
# Hashtags Used:['Braves']
#
# Tweet 76:
# Username:abraves277
# Description:Go Braves!!! Go USA!!!! You only live once so do it right!!! If you need the answer read your bible.God bless!!!!
# Location:greenville sc
# Following Count:327
# Follower Count:269
# Total Tweets:39354
# Retweet Count:0
# Tweet Text:@Fastaslightnin @MLB @astros @Braves 2 of the top 10 most popular teams with the Braves having one of the most broad viewerships of all teams and two heavily Latin teams playing. Yea I’m sure ratings will be in the tank. The Atlanta Braves are much bigger than the Atlanta market literally covering most of the south.
# Hashtags Used:[]
#
# Tweet 77:
# Username:trojandude
# Description:Misplaced ATL Braves & Falcons fan..... USC Trojans✌️ Lakers Santos Laguna... STAR WARS & anything cool. Do or Do Not, There is no try. UPS Driver
# Location:Mos Eisley Cantina
# Following Count:656
# Follower Count:436
# Total Tweets:28484
# Retweet Count:0
# Tweet Text:@18_4_LIFE @George_58_ Exactly we are all Braves country https://t.co/GLKiYzIMF1
# Hashtags Used:[]
#
# Tweet 78:
# Username:jason04940306
# Description:
# Location:
# Following Count:646
# Follower Count:321
# Total Tweets:5350
# Retweet Count:0
# Tweet Text:@DodgersJesse Not specifically directing anything at you. A general statement. I’ve read tweet after tweet today of nothing but excuse after excuse and nothing about giving credit to the Braves.
# Hashtags Used:[]
# Tweet 79:
# Username:MWLtraveler
# Description:Longtime tweeter of Midwest League things. Still use #MWLscoreboard for High-A Central scores. '10 years ago' tweets revisit my journey across the MWL in 2011.
# Location:Madison, WI
# Following Count:424
# Follower Count:1943
# Total Tweets:63705
# Retweet Count:405
# Tweet Text:Dusty Baker made his Major League debut with the Braves on September 7, 1968, in a game against the Astros. Now he’s going to be managing the Astros in the 2021 World Series against the Braves. Hang around long enough, and it all goes and comes around.
# Hashtags Used:[]
#
# Tweet 80:
# Username:CardsWithChris
# Description:@Patriots @Braves @Capitals | Those sports cards things are cool... Let’s make a deal! PC: Braves, Flagship Rookies & Cool Cards!
# Location:843
# Following Count:1936
# Follower Count:2742
# Total Tweets:9878
# Retweet Count:338
# Tweet Text:There is no one more excited that the #Braves are done with the Dodgers than Luke Jackson. Braves fans get fired up Luke especially when things don't go well, but I will say this, he is accountable. Great conversation after the NLCS clincher. https://t.co/fcgCUSKrjd
# Hashtags Used:['Braves']
#
# Tweet 81:
# Username:johnondrasik
# Description:Dad, Husband, Keys, Notes, Keynotes, Singer/Songwriter AKA Five For Fighting - GKG PWP 🛒🇺🇸 Blood on my Hands https://t.co/qUfmDf4R6h
# Location:Near Los Angeles
# Following Count:752
# Follower Count:17925
# Total Tweets:29732
# Retweet Count:1
# Tweet Text:May I join all of America in saying...Go @Braves!
# Hashtags Used:[]
#
# Tweet 82:
# Username:MarshallHarre13
# Description:I'm born and raised in the south. very honest to a fault. that's probably why I'm single
# Location:
# Following Count:1553
# Follower Count:793
# Total Tweets:24401
# Retweet Count:643
# Tweet Text:Atlanta Braves are in the World Series. Does that mean since Georgia is racist with their voting laws they will be moving the World Series to another city?
# Hashtags Used:[]
#
# Tweet 83:
# Username:hogrock57
# Description:
# Location:
# Following Count:963
# Follower Count:221
# Total Tweets:9165
# Retweet Count:643
# Tweet Text:Atlanta Braves are in the World Series. Does that mean since Georgia is racist with their voting laws they will be moving the World Series to another city?
# Hashtags Used:[]
#
# Tweet 84:
# Username:BritterrC
# Description:I got thick thighs, thin patience and a mouth that could run forever ➳
# Location:
# Following Count:490
# Follower Count:496
# Total Tweets:31822
# Retweet Count:0
# Tweet Text:Fun fact: while my mom was in labour with me, my dad was in the hospital room watching the Atlanta Braves win World Series. The news that the team is playing in the WS again made my dad tear up with joy… and my mom shake from ptsd 😂😂😂
# Hashtags Used:[]
#
# Tweet 85:
# Username:SethStuck
# Description:Curator of fine snark, sound logic and interesting context.
# ✝️🇺🇸🏈⚾
# 💡🧪📈💰
# Location:Atlanta, GA
# Following Count:694
# Follower Count:4145
# Total Tweets:30579
# Retweet Count:219
# Tweet Text:Umpire: Lance Barksdale
# Final: Braves 4, Dodgers 2
# #ForTheA // #Dodgers
# #ATLvsLAD // #LADvsATL https://t.co/TXXoMoXOy9
# Hashtags Used:['ForTheA', 'Dodgers', 'ATLvsLAD', 'LADvsATL']
#
# Tweet 86:
# Username:nobichattakun
# Description:ポッポ屋
# Location:
# Following Count:122
# Follower Count:101
# Total Tweets:29836
# Retweet Count:171
# Tweet Text:"I'm not going to hang my head... I'm just going to be happy for what we did and what we accomplished and tip my cap to the Braves." @mookiebetts on tonight's #Dodgers loss. https://t.co/NHeZBQ2tbx
# Hashtags Used:[]
#
# Tweet 87:
# Username:rpinson81
# Description:
# Location:33.873812,-84.192677
# Following Count:148
# Follower Count:13
# Total Tweets:1011
# Retweet Count:0
# Tweet Text:@MRiot @bethel1961 @pkpaddaddy @Travistritt @Braves Yeah, the areas where no one wants to live are red. Democratic Senators represent 41 million more constituents than Republican senators.
# Hashtags Used:[]
#
# Tweet 88:
# Username:hannahbakerjr
# Description:she/her! RIP HANNAH BAKER
# Location:California
# Following Count:198
# Follower Count:5743
# Total Tweets:47085
# Retweet Count:0
# Tweet Text:Thinking about how 2 of the padres games I went to were against the braves and the astros (we lost both of them of course lol) but I CAN SAY I’ve seen the World Series teams 😩😏
# Hashtags Used:[]
#
# Tweet 89:
# Username:Pjw20161951
# Description:Texas Constitutional Conservative “Trump Greatest President”  @SenTedCruz @TedCruz #CruzCrew #MAGAForever #NRA #NoAmnesty #FinishTheWall #StolenElection
# Location:Texas, USA
# Following Count:5810
# Follower Count:5124
# Total Tweets:335850
# Retweet Count:37
# Tweet Text:MLB told fans the Houston Astros are cheaters and the Atlanta Braves are racist. Now they’re both going to the World Series. It’s a thing of beauty, really.
# Hashtags Used:[]
#
# Tweet 90:
# Username:DsloanD
# Description:Husband & Father -|- Child here; Adult in real life -|- General Conversationalist -|- Baseball Cards -|- Braves -|- RAJr13 -|- Roka40 -|- OzzieA1 -|- 1 Thes 5
# Location:Florida, USA
# Following Count:2561
# Follower Count:1121
# Total Tweets:27443
# Retweet Count:0
# Tweet Text:My fellow Braves fans, when trash talking HOU fans please remember
#
# -they have a ring (no it wasn’t taken)
# -they have way more scars than we do
# -Dusty Baker is an MLB OG
# -they just might actually have a good team, maybe (thats the last compliment Im giving HOU)
#
# Trash talk wisely
# Hashtags Used:[]
#
# Tweet 91:
# Username:_MattBlair
# Description:I'm the youngest of 1 children. I was made to love Jesus & people. I'm not as funny as I think I am, which is a shame because I'm not that good looking either.
# Location:Right beside Carmen San Diego
# Following Count:990
# Follower Count:433
# Total Tweets:3404
# Retweet Count:0
# Tweet Text:@Cooperdc23 @BarrettSallee Maybe, just maybe, the Braves "only" won 88 games because they had to make those adjustments in the regular season. (They went through 3 lines of starting outfielders and like 7 catchers?) Maybe with all those losses the Dodgers are a lot closer to an 88 win team themselves.
# Hashtags Used:[]
#
# Tweet 92:
# Username:b_young08
# Description:I like sports. #geauxtigahs
# Location:Valdosta, GA
# Following Count:691
# Follower Count:910
# Total Tweets:16542
# Retweet Count:76
# Tweet Text:A picture worth a million words.
#
# I'm still thinking about Game 6, the #Braves' biggest win in over two decades and the #Postseason heroes who helped Atlanta make it back to the #WorldSeries. https://t.co/tpBnj4dzi9
# Hashtags Used:['Braves']
#
# Tweet 93:
# Username:UncleTerry19
# Description:Covid is your new 9/11. Germs instead of terrorists.
#
#
# MMA & ⚾
# Location:New Brunswick Canada
# Following Count:216
# Follower Count:46
# Total Tweets:7727
# Retweet Count:60
# Tweet Text:The Atlanta Braves making the World Series after 88 regular season wins: ☺️
#
# The Toronto Blue Jays missing the Wild Card after 91 regular season wins: 😞
# Hashtags Used:[]
#
# Tweet 94:
# Username:FlankerFoxy
# Description:I don’t hv tym fr games. Either b real or b gone..
# Location:
# Following Count:248
# Follower Count:1299
# Total Tweets:55586
# Retweet Count:44
# Tweet Text:#LestWeForgetIndia🇮🇳  THREE gallant #IndianBraves of 23 #AssamRifles @official_dgar
#  Hav Mohan Singh, Rfn Wangsoa Lowang &amp; Rfn Sunil Kumar Tiwari made the supreme sacrifice fighting terrorists #OnThisDay 25 October in 2007 in Tirap, #ArunachalPradesh
#
# Remember the Braves https://t.co/mwBypg8WUY
# Hashtags Used:['LestWeForgetIndia', 'IndianBraves', 'AssamRifles']
#
# Tweet 95:
# Username:RHbaseballFAITH
# Description:Head Baseball Coach; Special Teams Coordinator; Defensive Ends; ESL/ENG II/ENG II Honors; 2017 Secondary Teacher of the Year - RHISD 🍎🏈⚾️
# Location:Rio Hondo, TX
# Following Count:4347
# Follower Count:1990
# Total Tweets:15239
# Retweet Count:76
# Tweet Text:A picture worth a million words.
#
# I'm still thinking about Game 6, the #Braves' biggest win in over two decades and the #Postseason heroes who helped Atlanta make it back to the #WorldSeries. https://t.co/tpBnj4dzi9
# Hashtags Used:['Braves']
#
# Tweet 96:
# Username:AndySaleen
# Description:Poor Kid, SysAdmin, DevOps, InfoSec, Blue Team, Music, Lyricists, Guitar Solos, PoliSci, History, Liberalism, Sports, Liquor, Wine, and Women.
# Location:Nunya Creek
# Following Count:1886
# Follower Count:127
# Total Tweets:3518
# Retweet Count:2
# Tweet Text:Updated definitive guide of the NL East.
#
# Marlins: 🤡
# Nationals: 🚮
# Mets: 🚽
# Phillies: 🤮
# Braves: NL Champions
# Hashtags Used:[]
#
# Tweet 97:
# Username:coachice16
# Description:#UVA #Wizards #Braves
# Location:Virginia, USA
# Following Count:832
# Follower Count:239
# Total Tweets:97691
# Retweet Count:2
# Tweet Text:Both managers in the World Series are former Richmond Braves. Charlie Morton, too.
# Hashtags Used:[]
#
# Tweet 98:
# Username:getonboardkag24
# Description:Trump 2024, Proud Deplorable, MAGA 2024, Pro 2nd amendment, Pro Life, Conservative.
# Location:
# Following Count:1192
# Follower Count:495
# Total Tweets:14370
# Retweet Count:643
# Tweet Text:Atlanta Braves are in the World Series. Does that mean since Georgia is racist with their voting laws they will be moving the World Series to another city?
# Hashtags Used:[]
#
# Tweet 99:
# Username:edwardsweeney5
# Description:Retired
# Location:England, United Kingdom
# Following Count:676
# Follower Count:555
# Total Tweets:68368
# Retweet Count:643
# Tweet Text:Atlanta Braves are in the World Series. Does that mean since Georgia is racist with their voting laws they will be moving the World Series to another city?
# Hashtags Used:[]
#
# Tweet 100:
# Username:b3thanyand
# Description:
# Location:210
# Following Count:112
# Follower Count:205
# Total Tweets:4258
# Retweet Count:0
# Tweet Text:deadass took the day off for Braves game 1 💀
# Hashtags Used:[]
# Scraping has completed!
