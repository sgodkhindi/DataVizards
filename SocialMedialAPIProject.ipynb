# %%
# Import Environment Dependencies
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from config import api_key, api_key_secret, access_token,access_token_secret
from pprint import pprint
from datetime import date
from datetime import timedelta
from config import gkey
import requests
import urllib
from urllib.request import urlopen
import json
import gmaps

# %%
# Get Authentication and API Handle from Tweepy

auth = tweepy.OAuthHandler(consumer_key=api_key, consumer_secret=api_key_secret)

auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

# %%
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f"Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text:{ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")
    
    
 # function to perform data extraction
def scrape(words, location, date_since):
      
# Creating DataFrame using pandas
    db = pd.DataFrame(columns=['username', 'description', 'location', 'following',
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags'])
   
   
 # Creating a Cursor using the .Cursor() method to search through twitter for the required tweets.
    
    tweets = tweepy.Cursor(api.search_tweets,q=words, lang="en",
             tweet_mode='extended').items(100)
    
   
    list_tweets = [tweet for tweet in tweets]
      
    
    
      
    # we will iterate over each tweet in the list for extracting information about each tweet
    i = 1  
    for tweet in list_tweets:
        
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
        
        # Retweets can be distinguished by a retweeted_status attribute,
        # in case it is an invalid reference, except block will be executed
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
          
        # Here we are appending all the extracted information in the DataFrame
        ith_tweet = [username, description, location, following,
                     followers, totaltweets, retweetcount, text, hashtext]
        db.loc[len(db)] = ith_tweet
          
        # Function call to print tweet data on screen
        #printtweetdata(i, ith_tweet)
        i = i+1
    return db
        
        
        
        
    
#     filename = 'scraped_tweets.csv'
      
    # Saving the resultset as a CSV file.
#     db.to_csv(filename)

if __name__ == '__main__':
         
# Enter Hashtag and initial date
#     print("Enter Twitter HashTag to search for")
#     words = input()
#     print("Enter Date since The Tweets are required in yyyy-mm--dd")
#     date_since = input()
#     print("Enter Location of Tweets are required")
#     location = input()

    words='Braves'
    date_since='2021-10-18'
    location='Atlanta'
    db=scrape(words, location, date_since)
    print(db)
# Out:
#            username                                        description  \
# 0         5iveSeven                           No Limit 2.0 Drag Racing
# 1        CSeifertMT
# 2      Philliph0ang             Rest In Peace Kobe and Gigi 1/26/20 🙏🏼
# 3         Alexgg483  SPX Rugby🏉 SPX Football🏈 SPX 2022 |6'2 304| Pr...
# 4       ModestColin  ‘82 - INFJ - Empath - Houston Sports - Histori...
# ..              ...                                                ...
# 95  sourpatchzalich  #ForTheA #DUUUVAL #MagicTogether @ellaagalbrea...
# 96      BravesQueen  Breast cancer survivor. Crazy cat lady of 3.  ...
# 97     lianaaurbano                                          𖡼𖤣𖥧𖡼𓋼𖤣𖥧𓋼𓍊
# 98    LanierPatrick                                 #GoDawgs #GoBraves
# 99       the_boxer7                                        YOU A HOE‼️
#
#           location following followers totaltweets retweetcount  \
# 0                         61         4         472            0
# 1      Bozeman, MT        50       166        1708            0
# 2                        121       149        9517         2116
# 3      Houston, TX       404       153         286         2116
# 4   Houston Texas        513       179       26415          920
# ..             ...       ...       ...         ...          ...
# 95             386       630       608       29326            0
# 96     Atlanta, GA      1510      1212       24194          179
# 97    Edinburg, TX        40        37          46         2117
# 98      Austin, TX      1532       305        4897           19
# 99                       426       705       10562         2117
#
#                                                  text  hashtags
# 0   @WinfieIdJr @ATLSportStan @astros Ratio your r...        []
# 1   Astros and Braves sure doesn’t cut it… https:/...        []
# 2   Winners win.\n\nFinal: #Astros 7, Braves 2 htt...  [Astros]
# 3   Winners win.\n\nFinal: #Astros 7, Braves 2 htt...  [Astros]
# 4   What the hell did the @Braves do to Delaware 😂...        []
# ..                                                ...       ...
# 95  @MeekPhill_ It happens but that 2nd inning was...        []
# 96  Final: Astros 7, #Braves 2.\n\nWe’ll see you b...  [Braves]
# 97  Winners win.\n\nFinal: #Astros 7, Braves 2 htt...  [Astros]
# 98  The Braves got punched in the mouth in Game 5 ...        []
# 99  Winners win.\n\nFinal: #Astros 7, Braves 2 htt...  [Astros]
#
# [100 rows x 9 columns]

# %%
# db.head()
db_df = pd.DataFrame(db)
db_df
no_blnk_local_df = db_df.loc[(db_df['location'] !=""),:].sort_values('retweetcount',ascending=False).head(50)
no_blnk_local_df
# Out:
#            username                                        description  \
# 97     lianaaurbano                                          𖡼𖤣𖥧𖡼𓋼𖤣𖥧𓋼𓍊
# 57      saraberrett  23 | And she'll leave you with a smile. #TAMU2...
# 45    annavanness16                                 have a great day ☻
# 5     Simply_JazzyJ  Just a man tryna live fine as wine. Journalist...
# 64    marinachapa15                                               oghs
# 22      xxHTXKINGxx                                       🤘🏽🚀🐃⚾️🏈🏀🇸🇻🇲🇽
# 12      alexavierm0  Houston, TX 📍| Chavez HS 🐺 | ‘24 | Climate, Ra...
# 49   Dear_Samanthaa  Texas Forever. Jewels. Clothes. #smallbusiness...
# 3         Alexgg483  SPX Rugby🏉 SPX Football🏈 SPX 2022 |6'2 304| Pr...
# 81        aleaqui15                                              ♎️😙✌🏼
# 88      playboiijet                                          9teen*++!
# 46  OGRealMadridBOS
# 44      ThatsJustMC  Christian • UH Alumnus • BMW • Taylor’s Brothe...
# 36     duhlaykneeee  28. she/her. flutist. night owl. ☉♌︎ | ☽♏︎ | ↑...
# 38       catelynxox                                         girl mom 💛
# 35  GarrettMorlando
# 41   josue_rivera03                     THE University of Texas Alumni
# 4       ModestColin  ‘82 - INFJ - Empath - Houston Sports - Histori...
# 24        hlsmith_2
# 66      harlanbrose
# 79  SERIES TIED!! ⚾🔥\n@astros take #WorldSeries Ga...
# 34                           Braves in 6 I dont care.
# 48                           Braves in 6 I dont care.
# 39  ANOTHER BLOWOUT WINNER!💰\nMLB HOU ASTROS +1.5 ...
# 13  Kendall Graveman (5-1, 1.77 ERA) retires the B...
# 67  Native American groups pushed back Wednesday a...
# 86  Big hats, big hits, big win\n\n#Astros beat #B...
# 47  The Houston Astros stomp The Atlanta Braves 7-...
# 56  Hawks TT Under 112.5 (-125) ✅✅✅\nTimberwolves ...
# 61  @MAllenT12 @UmpireAuditor Part of the game isn...
# 9   I got to watch the Braves lose but what an exp...
# 11  National Congress of American Indians responde...
# 95  @MeekPhill_ It happens but that 2nd inning was...
# 16  Stand by what I say. Astros in 6.\nAstros win ...
# 93  @JamesMcdaven @camdenjm @Braves Bro as an Astr...
# 89  @cantguardjake Not surprising they stuck with ...
# 17  We will bounce back! I'm down with the split i...
# 18     The braves *had a 1-0 lead in the World Series
#
#                                              hashtags
# 97                                           [Astros]
# 57                                           [Astros]
# 45                                           [Astros]
# 5                                            [Astros]
# 64                                           [Astros]
# 22                                           [Astros]
# 12                                           [Astros]
# 49                                           [Astros]
# 3                                            [Astros]
# 81                                           [Astros]
# 88                                           [Astros]
# 46                                           [Astros]
# 44                                           [Astros]
# 36                                           [Astros]
# 38                                           [Astros]
# 35                                           [Astros]
# 41                                           [Astros]
# 4                                                  []
# 24                                                 []
# 66                                                 []
# 58                                           [Braves]
# 94                                           [Braves]
# 96                                           [Braves]
# 19                        [LoveOnTourAtlanta, Night1]
# 65                                      [WorldSeries]
# 43                                                 []
# 70                                                 []
# 20                                                 []
# 15                                                 []
# 52                                                 []
# 7                                                  []
# 98                                                 []
# 79                                      [WorldSeries]
# 34                                                 []
# 48                                                 []
# 39       [GamblingTwitter, MLB, ForTheH, WorldSeries]
# 13                                                 []
# 67                                                 []
# 86                 [Astros, Braves, WorldSeries, ATL]
# 47                                                 []
# 56  [freepicks, sportsbetting, bettingtips, bettin...
# 61                                                 []
# 9                                                  []
# 11                                                 []
# 95                                                 []
# 16                                                 []
# 93                                                 []
# 89                                                 []
# 17                                        [BattleATL]
# 18                                                 []

# %%
loc_lat= []
loc_long = []
loc_name=[]

for location in no_blnk_local_df['location']:
    location_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={gkey}"
    geo_data = requests.get(location_url).json()
    
    try:
        loc_lat.append(geo_data["results"][0]["geometry"]["location"]["lat"])
        loc_long.append(geo_data["results"][0]["geometry"]["location"]["lng"])
        loc_name.append(location)
    except IndexError:
        print("Index Out of Range")
        pass
    
# print(loc_lat)
# print(loc_long)
# print(loc_name)

# %%
data_df = {'Name' :loc_name, 'Latitude': loc_lat, 'Longitude':loc_long}
location_df = pd.DataFrame(data_df)
location_df["RetweetCount"] = no_blnk_local_df["retweetcount"] 
location_df = location_df.sort_values('RetweetCount',ascending=False).head(25)
location_df
# Out:
#                            Name   Latitude  Longitude RetweetCount
# 3       Houston TX 2 Atlanta GA  29.760427 -95.369803         2116
# 12                  Houston, TX  29.760427 -95.369803         2116
# 46                  Houston, TX  29.760427 -95.369803         2116
# 45                  Houston, Tx  29.760427 -95.369803         2116
# 22                  Atlanta, GA  33.748995 -84.387982         2116
# 49              New Jersey, USA  40.058324 -74.405661         2116
# 5                       Houston  29.760427 -95.369803         2116
# 36                376 LF Lounge  33.796351 -84.619377         2109
# 44                          386  29.618430 -81.203681         2109
# 41                  Atlanta, GA  33.748995 -84.387982         2109
# 38                       H Town  29.780998 -95.404557         2109
# 35                United States  37.090240 -95.712891         2109
# 4             orange grove , tx  27.956684 -97.936945          920
# 24                Charlotte, NC  35.227087 -80.843127          722
# 19             Connecticut, USA  41.603221 -73.087749          131
# 43                  Houston, TX  29.760427 -95.369803           51
# 7   Where the bluebonnets bloom  32.328712 -96.628151           48
# 20                  Atlanta, GA  33.748995 -84.387982           48
# 15          College Station, TX  30.627977 -96.334407           48
# 34                  Atlanta, GA  33.748995 -84.387982            4
# 48        Jacksonville Florida   30.332184 -81.655651            4
# 13    Houston, TX | Orlando, FL  29.731087 -95.468566            2
# 39                 Pearland, TX  29.563567 -95.286047            2
# 47                 Pearland, TX  29.563567 -95.286047            1
# 16                  Houston, TX  29.760427 -95.369803            0

# %%
# data_df = {'Latitude': loc_lat, 'Longitude':loc_long}
# coord_df = pd.DataFrame(data_df)
coord = location_df[["Latitude","Longitude"]]
popularity = location_df["RetweetCount"].astype(float)
print(coord)
print(popularity)
# Out:
#      Latitude  Longitude
# 3   29.760427 -95.369803
# 12  29.760427 -95.369803
# 46  29.760427 -95.369803
# 45  29.760427 -95.369803
# 22  33.748995 -84.387982
# 49  40.058324 -74.405661
# 5   29.760427 -95.369803
# 36  33.796351 -84.619377
# 44  29.618430 -81.203681
# 41  33.748995 -84.387982
# 38  29.780998 -95.404557
# 35  37.090240 -95.712891
# 4   27.956684 -97.936945
# 24  35.227087 -80.843127
# 19  41.603221 -73.087749
# 43  29.760427 -95.369803
# 7   32.328712 -96.628151
# 20  33.748995 -84.387982
# 15  30.627977 -96.334407
# 34  33.748995 -84.387982
# 48  30.332184 -81.655651
# 13  29.731087 -95.468566
# 39  29.563567 -95.286047
# 47  29.563567 -95.286047
# 16  29.760427 -95.369803
# 3     2116.0
# 12    2116.0
# 46    2116.0
# 45    2116.0
# 22    2116.0
# 49    2116.0
# 5     2116.0
# 36    2109.0
# 44    2109.0
# 41    2109.0
# 38    2109.0
# 35    2109.0
# 4      920.0
# 24     722.0
# 19     131.0
# 43      51.0
# 7       48.0
# 20      48.0
# 15      48.0
# 34       4.0
# 48       4.0
# 13       2.0
# 39       2.0
# 47       1.0
# 16       0.0
# Name: RetweetCount, dtype: float64

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(coord, weights=popularity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig1 = gmaps.figure(layout=figure_layout)

# %%
# Assign the marker layer to a variable
markers = gmaps.marker_layer(coord)

# Add the layer to the map
fig1.add_layer(markers)
fig1
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
